# %% [markdown]
# degree histogoram (random graph)
# https://networkx.github.io/documentation/stable/auto_examples/drawing/plot_degree_histogram.html

# %%
import collections
import matplotlib.pyplot as plt
import networkx as nx

G = nx.gnp_random_graph(100, 0.02)

degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

fig, ax = plt.subplots()
plt.bar(deg, cnt, width=0.80, color='b')

plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
ax.set_xticks([d + 0.4 for d in deg])
ax.set_xticklabels(deg)

# draw graph in inset
plt.axes([0.4, 0.4, 0.5, 0.5])
Gcc = sorted(nx.connected_component_subgraphs(G), key=len, reverse=True)[0]
pos = nx.spring_layout(G)
plt.axis('off')
nx.draw_networkx_nodes(G, pos, node_size=20)
nx.draw_networkx_edges(G, pos, alpha=0.4)

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# degree histogram (BA graph)

# %%
import collections
import matplotlib.pyplot as plt
import networkx as nx

G = nx.barabasi_albert_graph(100, 1) #only this line is changed

degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

fig, ax = plt.subplots()
plt.bar(deg, cnt, width=0.80, color='b')

plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
ax.set_xticks([d + 0.4 for d in deg])
ax.set_xticklabels(deg)

# draw graph in inset
plt.axes([0.4, 0.4, 0.5, 0.5])
Gcc = sorted(nx.connected_component_subgraphs(G), key=len, reverse=True)[0]
pos = nx.spring_layout(G)
plt.axis('off')
nx.draw_networkx_nodes(G, pos, node_size=20)
nx.draw_networkx_edges(G, pos, alpha=0.4)

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# configuration model

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

z = [5, 3, 3, 3, 3, 2, 2, 2, 1, 1, 1]
G = nx.configuration_model(z)
plt.figure(figsize=(5, 5))
nx.draw_spring(G, node_size=200, node_color="red", with_labels=True, font_weight='bold')
# Out:
# /usr/local/lib/python3.6/dist-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# preferential attachment

# %%
import networkx as nx
import matplotlib.pyplot as plt

plt.subplot(241)
G = nx.barabasi_albert_graph(20,2)
nx.draw_spring(G, node_size=200, node_color="red", with_labels=True, font_weight='bold')
plt.subplot(245)
plt.plot(nx.degree_histogram(G))
plt.subplot(242)
G = nx.barabasi_albert_graph(40,2)
nx.draw_spring(G, node_size=200, node_color="red", with_labels=True, font_weight='bold')
plt.subplot(246)
plt.plot(nx.degree_histogram(G))
plt.subplot(243)
G = nx.barabasi_albert_graph(60,2)
nx.draw_spring(G, node_size=200, node_color="red", with_labels=True, font_weight='bold')
plt.subplot(247)
plt.plot(nx.degree_histogram(G))
plt.subplot(244)
G = nx.barabasi_albert_graph(80,2)
nx.draw_spring(G, node_size=200, node_color="red", with_labels=True, font_weight='bold')
plt.subplot(248)
plt.plot(nx.degree_histogram(G))
# Out:
# /usr/local/lib/python3.6/dist-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# log-log plot

# %%
import networkx as nx
import collections
#import numpy as np
import matplotlib.pyplot as plt
from networkx.utils.random_sequence import powerlaw_sequence

er = nx.erdos_renyi_graph(10000, 0.001)
print("Erdos-Renyi graph")
print(nx.info(er))
print("Number of connected components: ",nx.number_connected_components(er)) # 2ln(n)/n -> 0 when n -> inf
print("Number of triangles: ", sum(nx.triangles(er).values())//3)
print("Transitivity: ",nx.transitivity(er))
maxi = max(list(er.degree()), key = lambda x: x[1])
print("Maximum degree: ", maxi[1])
mini = min(list(er.degree()), key = lambda x: x[1])
print("Minimum degree: ", mini[1])
# plt.subplot(221)
# plt.plot(nx.degree_histogram(er))
degree_sequence = sorted([d for n, d in er.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

fig, ax = plt.subplots()
plt.subplot(121)
plt.bar(deg, cnt, width=0.80, color='b')

plt.title("Erdos-Renyi Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
ax.set_xticks([d + 0.4 for d in deg])
ax.set_xticklabels(deg)


print()
ba = nx.barabasi_albert_graph(10000, 5)
print("Barabasi-Albert graph")
print(nx.info(ba))
print("Number of connected components: ",nx.number_connected_components(ba)) # 2ln(n)/n -> 0 when n -> inf
print("Number of triangles: ", sum(nx.triangles(ba).values())//3)
print("Transitivity: ",nx.transitivity(ba))
maxi = max(list(ba.degree()), key = lambda x: x[1])
print("Maximum degree: ", maxi[1])
mini = min(list(ba.degree()), key = lambda x: x[1])
print("Minimum degree: ", mini[1])
# plt.subplot(222)
# plt.plot(nx.degree_histogram(ba))
degree_sequence = sorted([d for n, d in ba.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

plt.subplot(122)
plt.bar(deg, cnt, width=0.80, color='b')

plt.title("Barabasi-Albert Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
ax.set_xticks([d + 0.4 for d in deg])
ax.set_xticklabels(deg)



# # plot logarithmic axes
# plt.subplot(223)
# plt.xscale("log")
# plt.yscale("log")
# plt.grid(which="both")
# plt.plot(nx.degree_histogram(er))
# plt.subplot(224)
# plt.xscale("log")
# plt.yscale("log")
# plt.grid(which="both")
# plt.plot(nx.degree_histogram(ba))
# Out:
# Erdos-Renyi graph
# Name:
# Type: Graph
# Number of nodes: 10000
# Number of edges: 49805
# Average degree:   9.9610
# Number of connected components:  1
# Number of triangles:  169
# Transitivity:  0.001022579441514305
# Maximum degree:  27
# Minimum degree:  1
#
# Barabasi-Albert graph
# Name:
# Type: Graph
# Number of nodes: 10000
# Number of edges: 49975
# Average degree:   9.9950
# Number of connected components:  1
# Number of triangles:  2150
# Transitivity:  0.005056899924342505
# Maximum degree:  348
# Minimum degree:  5
# [Text(0, 0, '348'),
#  Text(0, 0, '339'),
#  Text(0, 0, '333'),
#  Text(0, 0, '250'),
#  Text(0, 0, '243'),
#  Text(0, 0, '224'),
#  Text(0, 0, '218'),
#  Text(0, 0, '217'),
#  Text(0, 0, '197'),
#  Text(0, 0, '175'),
#  Text(0, 0, '172'),
#  Text(0, 0, '169'),
#  Text(0, 0, '168'),
#  Text(0, 0, '167'),
#  Text(0, 0, '162'),
#  Text(0, 0, '154'),
#  Text(0, 0, '148'),
#  Text(0, 0, '146'),
#  Text(0, 0, '133'),
#  Text(0, 0, '132'),
#  Text(0, 0, '130'),
# ...

# %% [markdown]
# small world

# %%
import networkx as nx
import matplotlib.pyplot as plt

plt.subplot(241)
G = nx.watts_strogatz_graph(20, 4, 0.1)
nx.draw_circular(G, node_size=50)
plt.subplot(245)
plt.plot(nx.degree_histogram(G))
plt.subplot(242)
G = nx.watts_strogatz_graph(20, 4, 0.3)
nx.draw_circular(G, node_size=50)
plt.subplot(246)
plt.plot(nx.degree_histogram(G))
plt.subplot(243)
G = nx.watts_strogatz_graph(20, 4, 0.5)
nx.draw_circular(G, node_size=50)
plt.subplot(247)
plt.plot(nx.degree_histogram(G))
plt.subplot(244)
G = nx.watts_strogatz_graph(20, 4, 0.7)
nx.draw_circular(G, node_size=50)
plt.subplot(248)
plt.plot(nx.degree_histogram(G))
# Out:
# /usr/local/lib/python3.6/dist-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
